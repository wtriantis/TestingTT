# %%
import requests

url = "https://api.messari.io/asset/v1/assets"

headers = {
    "accept": "application/json",
    "x-messari-api-key": "a2b40fb9-2456-4f31-a468-f7693ecee242"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"error":null,"data":[{"id":"1e31218a-e44e-4285-820c-8282ee222035","serialId":6057,"symbol":"BTC","name":"Bitcoin","slug":"bitcoin","rank":1,"category":"Cryptocurrency","sector":"Cryptocurrency","tags":["Proof-of-Work"]},{"id":"21c795f5-1bfd-40c3-858e-e9d7e820c6d0","serialId":6059,"symbol":"ETH","name":"Ethereum","slug":"ethereum","rank":2,"category":"Networks","sector":"Smart Contract Platform","tags":["EVM","Proof-of-Stake","Stakeable"]},{"id":"51f8ea5e-f426-4f40-939a-db7e05495374","serialId":140,"symbol":"USDT","name":"Tether","slug":"tether","rank":3,"category":"Cryptocurrency","sector":"Stablecoins","tags":["Centralized Issuer","U.S. Dollar Stablecoin"]},{"id":"7dc551ba-cfed-4437-a027-386044415e3e","serialId":347,"symbol":"BNB","name":"BNB","slug":"binance-coin","rank":4,"category":"Networks","sector":"Smart Contract Platform","tags":["Centralized Exchange","Cosmos SDK","EVM","SEC Alleged Securities"]},{"id":"b3d5d66c-26a2-404c-9325-91dc714a722b","serialId":6079,"symbol":"SOL","
# ...

# %%
headers = {
    "Authorization": "{{token_terminal_api_1}}",
}
params = {
    "metric_id": "price",
    "project_ids": "bitcoin,ethereum",
    "start": "09-01-2022",
    "end": "09-01-2023",
}
url = "https://api.tokenterminal.com/v2/metrics/{metric_id}".format(**params)
result = requests.get(url, headers=headers, params=params).json()
