# %%
import requests
import pandas as pd
from tabulate import tabulate
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}

# List Projects
projects_url = 'https://api.tokenterminal.com/v2/projects'
projects_response = requests.get(projects_url, headers=headers)

if projects_response.status_code == 200:
    projects = projects_response.json()
    projects_df = pd.DataFrame(projects)
    print("Projects:")
    print(tabulate(projects_df, headers='keys', tablefmt='psql'))
else:
    print(f'Failed to retrieve projects: {projects_response.status_code}')
    print(projects_response.text)

# List Metrics
metrics_url = 'https://api.tokenterminal.com/v2/metrics'
metrics_response = requests.get(metrics_url, headers=headers)

if metrics_response.status_code == 200:
    metrics = metrics_response.json()
    metrics_df = pd.DataFrame(metrics)
    print("Metrics:")
    print(tabulate(metrics_df, headers='keys', tablefmt='psql'))
else:
    print(f'Failed to retrieve metrics: {metrics_response.status_code}')
    print(metrics_response.text)
# Out:
# Projects:
# +-----+----------------------------------------------------------------------------------------------------------------------------------------+
# |     | data                                                                                                                                   |
# |-----+----------------------------------------------------------------------------------------------------------------------------------------|
# |   0 | {'name': '0x', 'project_id': '0x', 'symbol': 'ZRX', 'url': '/v2/projects/0x'}                                                          |
# |   1 | {'name': '1inch', 'project_id': '1inch', 'symbol': '1INCH', 'url': '/v2/projects/1inch'}                                               |
# |   2 | {'name': 'Aave', 'project_id': 'aave', 'symbol': 'AAVE', 'url': '/v2/projects/aave'}                                                   |
# ...

# %%
import requests
import pandas as pd
from tabulate import tabulate

# Replace 'your_api_key_here' with your actual Token Terminal API key
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}

url = "https://api.tokenterminal.com/v2/metrics/price"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"message":"invalid token"}

# %%
import requests
import pandas as pd
from tabulate import tabulate

# Replace 'your_api_key_here' with your actual Token Terminal API key
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}
# Define the endpoint you want to hit
url = 'https://api.tokenterminal.com/v2/projects'  # Replace <your-endpoint> with the specific endpoint you want to access

# Make the request to the API
response = requests.get(url, headers=headers)

# Check if the request was successful


# After converting the data to a DataFrame
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    print(tabulate(df, headers='keys', tablefmt='psql'))
else:
    print(f'Failed to retrieve data: {response.status_code}')
    print(response.text)
# Out:
# +-----+----------------------------------------------------------------------------------------------------------------------------------------+
# |     | data                                                                                                                                   |
# |-----+----------------------------------------------------------------------------------------------------------------------------------------|
# |   0 | {'name': '0x', 'project_id': '0x', 'symbol': 'ZRX', 'url': '/v2/projects/0x'}                                                          |
# |   1 | {'name': '1inch', 'project_id': '1inch', 'symbol': '1INCH', 'url': '/v2/projects/1inch'}                                               |
# |   2 | {'name': 'Aave', 'project_id': 'aave', 'symbol': 'AAVE', 'url': '/v2/projects/aave'}                                                   |
# ...

# %%
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}

# List Projects
projects_url = 'https://api.tokenterminal.com/v2/projects'
projects_response = requests.get(projects_url, headers=headers)

if projects_response.status_code == 200:
    projects = projects_response.json()
    projects_df = pd.DataFrame(projects)
    print("Projects:")
    print(tabulate(projects_df, headers='keys', tablefmt='psql'))
else:
    print(f'Failed to retrieve projects: {projects_response.status_code}')
    print(projects_response.text)

# List Metrics
metrics_url = 'https://api.tokenterminal.com/v2/metrics'
metrics_response = requests.get(metrics_url, headers=headers)

if metrics_response.status_code == 200:
    metrics = metrics_response.json()
    metrics_df = pd.DataFrame(metrics)
    print("Metrics:")
    print(tabulate(metrics_df, headers='keys', tablefmt='psql'))
else:
    print(f'Failed to retrieve metrics: {metrics_response.status_code}')
    print(metrics_response.text)
# Out:
# Projects:
# +-----+----------------------------------------------------------------------------------------------------------------------------------------+
# |     | data                                                                                                                                   |
# |-----+----------------------------------------------------------------------------------------------------------------------------------------|
# |   0 | {'name': '0x', 'project_id': '0x', 'symbol': 'ZRX', 'url': '/v2/projects/0x'}                                                          |
# |   1 | {'name': '1inch', 'project_id': '1inch', 'symbol': '1INCH', 'url': '/v2/projects/1inch'}                                               |
# |   2 | {'name': 'Aave', 'project_id': 'aave', 'symbol': 'AAVE', 'url': '/v2/projects/aave'}                                                   |
# ...

# %%
import pandas as pd
import requests

# Define API key and headers
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}

# Fetch available projects
projects_url = 'https://api.tokenterminal.com/v2/projects'
projects_response = requests.get(projects_url, headers=headers)

if projects_response.status_code == 200:
    projects = projects_response.json()
    projects_df = pd.DataFrame(projects)
    print("Projects DataFrame Columns:")
    print(projects_df.columns)
    print("Projects:")
    print(projects_df.head())
else:
    print(f'Failed to retrieve projects: {projects_response.status_code}')
    print(projects_response.text)

# Fetch available metrics
metrics_url = 'https://api.tokenterminal.com/v2/metrics'
metrics_response = requests.get(metrics_url, headers=headers)

if metrics_response.status_code == 200:
    metrics = metrics_response.json()
    metrics_df = pd.DataFrame(metrics)
    print("Metrics DataFrame Columns:")
    print(metrics_df.columns)
    print("Metrics:")
    print(metrics_df.head())
else:
    print(f'Failed to retrieve metrics: {metrics_response.status_code}')
    print(metrics_response.text)
# Out:
# Projects DataFrame Columns:
# Index(['data'], dtype='object')
# Projects:
#                                                 data
# 0  {'name': '0x', 'project_id': '0x', 'symbol': '...
# 1  {'name': '1inch', 'project_id': '1inch', 'symb...
# 2  {'name': 'Aave', 'project_id': 'aave', 'symbol...
# 3  {'name': 'Aave GHO', 'project_id': 'aavegho', ...
# 4  {'name': 'Abracadabra.money', 'project_id': 'a...
# Metrics DataFrame Columns:
# Index(['data'], dtype='object')
# Metrics:
#                                                 data
# 0  {'metric_id': 'price', 'metric_name': 'Price',...
# 1  {'metric_id': 'market_cap_fully_diluted', 'met...
# 2  {'metric_id': 'market_cap_circulating', 'metri...
# 3  {'metric_id': 'token_trading_volume', 'metric_...
# 4  {'metric_id': 'token_turnover_fully_diluted', ...

# %%
import pandas as pd
import requests

# Define API key and headers
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}

url = "https://api.tokenterminal.com/v2/metrics/price"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"message":"invalid token"}

# %%
import requests

# Define API key and headers
api_key = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'
headers = {
    'Authorization': f'Bearer {api_key}',
}

# Try accessing a simple endpoint that requires authentication
projects_url = 'https://api.tokenterminal.com/v2/projects'
response = requests.get(projects_url, headers=headers)

if response.status_code == 200:
    print("Token is valid. Projects retrieved successfully.")
else:
    print(f'Failed to retrieve projects: {response.status_code}')
    print("Response Text:", response.text)
    if response.status_code == 401:
        print("Unauthorized: The token might be invalid or expired.")
    elif response.status_code == 403:
        print("Forbidden: The token does not have the necessary permissions.")
    else:
        print("Other error. Please check the API documentation or contact support.")
# Out:
# Token is valid. Projects retrieved successfully.

# %%
import pandas as pd

# Assuming the fetch_projects and fetch_metrics functions are already defined and provided

projects = fetch_projects()
metrics = fetch_metrics()

# Adding debug print statements to inspect the structure of the projects variable
print("Type of projects variable:", type(projects))
print("Content of projects variable:", projects)

# Checking if projects is a dictionary and contains the expected structure
if isinstance(projects, dict) and 'data' in projects:
    projects_data = projects['data']
    print("Type of projects data:", type(projects_data))
    print("First few elements of projects data:")
    for proj in projects_data[:5]:  # Print the first 5 elements if it's a list
        print(proj)

    if isinstance(projects_data, list):
        projects_df = pd.DataFrame(projects_data)
        print("Projects DataFrame Columns:")
        print(projects_df.columns)
        display(projects_df.head())  # Display the first few rows of the DataFrame for verification
else:
    print("Projects variable does not have the expected structure.")

# Similarly for metrics
if isinstance(metrics, dict) and 'data' in metrics:
    metrics_data = metrics['data']
    print("Type of metrics data:", type(metrics_data))
    print("First few elements of metrics data:")
    for metric in metrics_data[:5]:  # Print the first 5 elements if it's a list
        print(metric)

    if isinstance(metrics_data, list):
        metrics_df = pd.DataFrame(metrics_data)
        print("Metrics DataFrame Columns:")
        print(metrics_df.columns)
        display(metrics_df.head())  # Display the first few rows of the DataFrame for verification
else:
    print("Metrics variable does not have the expected structure.")
# Out:
# Type of projects variable: <class 'dict'>
# ...

# %%
import pandas as pd

# Extracting data from the projects dictionary
projects_data = projects['data']

# Creating a DataFrame from the projects data
projects_df = pd.DataFrame(projects_data)

# Limiting the DataFrame to 500 data points
projects_df_sample = projects_df.head(500)

# Display the DataFrame sample
projects_df_sample.head()
# Out:
#                 name         project_id symbol                             url
# 0                 0x                 0x    ZRX                 /v2/projects/0x
# 1              1inch              1inch  1INCH              /v2/projects/1inch
# 2               Aave               aave   AAVE               /v2/projects/aave
# 3           Aave GHO            aavegho    GHO            /v2/projects/aavegho
# 4  Abracadabra.money  abracadabra-money  SPELL  /v2/projects/abracadabra-money

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Replace 'your_api_key' with your actual Token Terminal API key
API_KEY = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'

# Define the base URL for the Token Terminal API
BASE_URL = 'https://api.tokenterminal.com/v2'

# Function to fetch projects
def fetch_projects():
    url = f'{BASE_URL}/projects'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch metrics
def fetch_metrics():
    url = f'{BASE_URL}/metrics'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch time-series data
def fetch_time_series_data(project_id, metric_id, start_date, end_date):
    url = f'{BASE_URL}/projects/{project_id}/metrics/{metric_id}/timeseries'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    params = {
        'start_date': start_date,
        'end_date': end_date
    }
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 404:
        print(f"Data for project ID '{project_id}' or metric ID '{metric_id}' not found.")
        return pd.DataFrame()  # Return an empty DataFrame if not found
    response.raise_for_status()  # Raise an exception for other HTTP errors
    data = response.json()['data']
    return pd.DataFrame(data)

# Function to plot time series data
def plot_time_series(data, project_name, metric_name):
    if data.empty:
        print(f"No data available for {project_name} - {metric_name}")
        return
    plt.figure(figsize=(10, 6))
    plt.plot(data['timestamp'], data['value'], marker='o')
    plt.title(f'{metric_name} Over Time for {project_name}')
    plt.xlabel('Date')
    plt.ylabel(metric_name)
    plt.grid(True)
    plt.show()

# Example usage
if __name__ == "__main__":
    projects = fetch_projects()
    metrics = fetch_metrics()

    # Convert projects and metrics to DataFrame for easier manipulation
    projects_df = pd.DataFrame(projects['data'])
    metrics_df = pd.DataFrame(metrics['data'])

    # Display the first few rows of the DataFrames
    print(projects_df.head())
    print(metrics_df.head())

    # Example project and metric IDs
    project_id = '0x'  # Example project ID
    metric_id = 'price'  # Example metric ID
    start_date = '2023-01-01'
    end_date = '2023-12-31'

    # Fetch time series data
    time_series_data = fetch_time_series_data(project_id, metric_id, start_date, end_date)
    print(time_series_data.head())

    # Plot the time series data
    if not time_series_data.empty:
        project_name = projects_df[projects_df['project_id'] == project_id]['name'].values[0]
        metric_name = metrics_df[metrics_df['metric_id'] == metric_id]['metric_name'].values[0]
        plot_time_series(time_series_data, project_name, metric_name)
# Out:
#                 name         project_id symbol                             url
# 0                 0x                 0x    ZRX                 /v2/projects/0x
# 1              1inch              1inch  1INCH              /v2/projects/1inch
# 2               Aave               aave   AAVE               /v2/projects/aave
# 3           Aave GHO            aavegho    GHO            /v2/projects/aavegho
# 4  Abracadabra.money  abracadabra-money  SPELL  /v2/projects/abracadabra-money
#                       metric_id                     metric_name  \
# 0                         price                           Price
# 1      market_cap_fully_diluted      Market cap (fully diluted)
# 2        market_cap_circulating        Market cap (circulating)
# 3          token_trading_volume            Token trading volume
# 4  token_turnover_fully_diluted  Token turnover (fully diluted)
#
#                                          description  \
# 0  average USD value of the protocol’s governance...
# ...

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# Replace 'your_api_key' with your actual Token Terminal API key
API_KEY = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'

# Define the base URL for the Token Terminal API
BASE_URL = 'https://api.tokenterminal.com/v2'

# Function to fetch projects
def fetch_projects():
    url = f'{BASE_URL}/projects'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch metrics
def fetch_metrics():
    url = f'{BASE_URL}/metrics'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch time-series data
def fetch_time_series_data(metric_id):
    url = f'{BASE_URL}/metrics/{metric_id}'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for other HTTP errors
    data = response.json()['data']
    return pd.DataFrame(data)

# Function to plot time series data
def plot_time_series(data, metric_name):
    if data.empty:
        print(f"No data available for {metric_name}")
        return
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    plt.figure(figsize=(10, 6))
    for project_id, group in data.groupby('project_id'):
        plt.plot(group['timestamp'], group['value'], marker='o', label=project_id)
    plt.title(f'{metric_name} Over Time for Multiple Projects')
    plt.xlabel('Date')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
if __name__ == "__main__":
    # Fetch projects and metrics data
    projects = fetch_projects()
    metrics = fetch_metrics()

    # Convert projects and metrics to DataFrame for easier manipulation
    projects_df = pd.DataFrame(projects['data'])
    metrics_df = pd.DataFrame(metrics['data'])

    # Display the first few rows of the DataFrames
    print(projects_df.head())
    print(metrics_df.head())

    # Example metric ID for fetching time-series data
    metric_id = 'price'  # Example metric ID

    # Fetch time series data for the given metric
    time_series_data = fetch_time_series_data(metric_id)
    print(time_series_data.head())

    # Plot the time series data
    metric_name = metrics_df[metrics_df['metric_id'] == metric_id]['metric_name'].values[0]
    plot_time_series(time_series_data, metric_name)
# Out:
#                 name         project_id symbol                             url
# 0                 0x                 0x    ZRX                 /v2/projects/0x
# 1              1inch              1inch  1INCH              /v2/projects/1inch
# 2               Aave               aave   AAVE               /v2/projects/aave
# 3           Aave GHO            aavegho    GHO            /v2/projects/aavegho
# 4  Abracadabra.money  abracadabra-money  SPELL  /v2/projects/abracadabra-money
#                       metric_id                     metric_name  \
# 0                         price                           Price
# 1      market_cap_fully_diluted      Market cap (fully diluted)
# 2        market_cap_circulating        Market cap (circulating)
# 3          token_trading_volume            Token trading volume
# 4  token_turnover_fully_diluted  Token turnover (fully diluted)
#
#                                          description  \
# 0  average USD value of the protocol’s governance...
# ...

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Replace 'your_api_key' with your actual Token Terminal API key
API_KEY = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'

# Define the base URL for the Token Terminal API
BASE_URL = 'https://api.tokenterminal.com/v2'

# Function to fetch projects
def fetch_projects():
    url = f'{BASE_URL}/projects'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch metrics
def fetch_metrics():
    url = f'{BASE_URL}/metrics'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch time-series data with caching
def fetch_time_series_data(metric_id, project_ids, start_date, end_date):
    cache = {}
    for project_id in project_ids:
        if project_id in cache:
            continue
        url = f'{BASE_URL}/metrics/{metric_id}'
        headers = {
            'Authorization': f'Bearer {API_KEY}'
        }
        params = {
            'start_date': start_date,
            'end_date': end_date,
            'project_ids': project_id
        }
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 404:
            print(f"Data for project ID '{project_id}' or metric ID '{metric_id}' not found.")
            continue
        response.raise_for_status()  # Raise an exception for other HTTP errors
        data = response.json()['data']
        cache[project_id] = pd.DataFrame(data)
    return cache

# Function to plot time series data
def plot_time_series(data_dict, metric_name):
    plt.figure(figsize=(10, 6))
    for project_id, data in data_dict.items():
        if data.empty:
            continue
        data['timestamp'] = pd.to_datetime(data['timestamp'])
        plt.plot(data['timestamp'], data['value'], marker='o', label=project_id)
    plt.title(f'{metric_name} Over Time for Selected Projects')
    plt.xlabel('Date')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
if __name__ == "__main__":
    # Fetch projects and metrics data
    projects = fetch_projects()
    metrics = fetch_metrics()

    # Convert projects and metrics to DataFrame for easier manipulation
    projects_df = pd.DataFrame(projects['data'])
    metrics_df = pd.DataFrame(metrics['data'])

    # Display the first few rows of the DataFrames
    print(projects_df.head())
    print(metrics_df.head())

    # Example metric ID for fetching time-series data
    metric_id = 'price'  # Example metric ID

    # Limit to a subset of project IDs
    project_ids = ['0x', '1inch', 'aave','bitcoin','ethereum']  # Example project IDs
    start_date = '2023-01-01'
    end_date = '2023-12-31'

    # Fetch time series data for the given metric and project IDs
    time_series_data = fetch_time_series_data(metric_id, project_ids, start_date, end_date)

    # Plot the time series data
    metric_name = metrics_df[metrics_df['metric_id'] == metric_id]['metric_name'].values[0]
    plot_time_series(time_series_data, metric_name)
# Out:
#                 name         project_id symbol                             url
# 0                 0x                 0x    ZRX                 /v2/projects/0x
# 1              1inch              1inch  1INCH              /v2/projects/1inch
# 2               Aave               aave   AAVE               /v2/projects/aave
# 3           Aave GHO            aavegho    GHO            /v2/projects/aavegho
# 4  Abracadabra.money  abracadabra-money  SPELL  /v2/projects/abracadabra-money
#                       metric_id                     metric_name  \
# 0                         price                           Price
# 1      market_cap_fully_diluted      Market cap (fully diluted)
# 2        market_cap_circulating        Market cap (circulating)
# 3          token_trading_volume            Token trading volume
# 4  token_turnover_fully_diluted  Token turnover (fully diluted)
#
#                                          description  \
# 0  average USD value of the protocol’s governance...
# ...

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Replace 'your_api_key' with your actual Token Terminal API key
API_KEY = '2acb79dd-f8ca-48b5-b10c-bbee2290ed94'

# Define the base URL for the Token Terminal API
BASE_URL = 'https://api.tokenterminal.com/v2'

# Function to fetch projects
def fetch_projects():
    url = f'{BASE_URL}/projects'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch metrics
def fetch_metrics():
    url = f'{BASE_URL}/metrics'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    return response.json()

# Function to fetch time-series data with caching
def fetch_time_series_data(metric_id, project_ids, start_date, end_date):
    cache = {}
    project_ids_str = ','.join(project_ids)
    url = f'{BASE_URL}/metrics/{metric_id}'
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }
    params = {
        'project_ids': project_ids_str,
        'start': start_date,
        'end': end_date
    }
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 404:
        print(f"Data for projects or metric ID '{metric_id}' not found.")
        return cache
    response.raise_for_status()  # Raise an exception for other HTTP errors
    data = response.json()['data']
    
    for entry in data:
        project_id = entry['project_id']
        if project_id not in cache:
            cache[project_id] = []
        cache[project_id].append(entry)
    
    for project_id in cache:
        cache[project_id] = pd.DataFrame(cache[project_id])
    
    return cache

# Function to plot time series data
def plot_time_series(data_dict, metric_name):
    plt.figure(figsize=(10, 6))
    for project_id, data in data_dict.items():
        if data.empty:
            continue
        data['timestamp'] = pd.to_datetime(data['timestamp'])
        plt.plot(data['timestamp'], data['value'], marker='o', label=project_id)
    plt.title(f'{metric_name} Over Time for Selected Projects')
    plt.xlabel('Date')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
if __name__ == "__main__":
    # Fetch projects and metrics data
    projects = fetch_projects()
    metrics = fetch_metrics()

    # Convert projects and metrics to DataFrame for easier manipulation
    projects_df = pd.DataFrame(projects['data'])
    metrics_df = pd.DataFrame(metrics['data'])

    # Display the first few rows of the DataFrames
    print(projects_df.head())
    print(metrics_df.head())

    # Example metric ID for fetching time-series data
    metric_id = 'price'  # Example metric ID

    # Limit to a subset of project IDs
    project_ids = ['0x', '1inch', 'aave','bitcoin','ethereum']  # Example project IDs
    start_date = '2023-01-01'
    end_date = '2023-12-31'

    # Fetch time series data for the given metric and project IDs
    time_series_data = fetch_time_series_data(metric_id, project_ids, start_date, end_date)

    # Plot the time series data
    metric_name = metrics_df[metrics_df['metric_id'] == metric_id]['metric_name'].values[0]
    plot_time_series(time_series_data, metric_name)
# Out:
#                 name         project_id symbol                             url
# 0                 0x                 0x    ZRX                 /v2/projects/0x
# 1              1inch              1inch  1INCH              /v2/projects/1inch
# 2               Aave               aave   AAVE               /v2/projects/aave
# 3           Aave GHO            aavegho    GHO            /v2/projects/aavegho
# 4  Abracadabra.money  abracadabra-money  SPELL  /v2/projects/abracadabra-money
#                       metric_id                     metric_name  \
# 0                         price                           Price
# 1      market_cap_fully_diluted      Market cap (fully diluted)
# 2        market_cap_circulating        Market cap (circulating)
# 3          token_trading_volume            Token trading volume
# 4  token_turnover_fully_diluted  Token turnover (fully diluted)
#
#                                          description  \
# 0  average USD value of the protocol’s governance...
# ...

# %%
print(time_series_data)
# Out:
# {'0x':                     timestamp project_name project_id metric_id     value
# 0   2023-12-31 00:00:00+00:00           0x         0x     price  0.369590
# 1   2023-12-30 00:00:00+00:00           0x         0x     price  0.364295
# 2   2023-12-29 00:00:00+00:00           0x         0x     price  0.364182
# 3   2023-12-28 00:00:00+00:00           0x         0x     price  0.370844
# 4   2023-12-27 00:00:00+00:00           0x         0x     price  0.363216
# ..                        ...          ...        ...       ...       ...
# 360 2023-01-05 00:00:00+00:00           0x         0x     price  0.157607
# 361 2023-01-04 00:00:00+00:00           0x         0x     price  0.156980
# 362 2023-01-03 00:00:00+00:00           0x         0x     price  0.153623
# 363 2023-01-02 00:00:00+00:00           0x         0x     price  0.155190
# 364 2023-01-01 00:00:00+00:00           0x         0x     price  0.150259
#
# ...
